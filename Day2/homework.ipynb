# %% [markdown]
# Write a python program that asks the user to enter a sentence and perform following tasks:
#
# 1. Remove leading and trailing spaces.
# 2. Create a new string formed by taking the first character of each word of the sentence.
# 3. Convert the new string to upper and lower case.
# 5. Print the generated string.

# %%
aim = input("Enter a sentence:")

# %%
print(aim)
# Out:
#  Hello my name is uzair and i am CSE Student

# %%
print(aim.strip())   # removes the leading and trailing spaces from the input string
# Out:
# Hello my name is uzair and i am CSE Student

# %%
# String from first character of each word

words = aim.split()
new = ""

for word in words:
    new = new + word[0]
    
print(new)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 # String from first character of each word
# ----> 3 words = aim.split()
#       4 new = ""
#       6 for word in words:
#
# NameError: name 'aim' is not defined
