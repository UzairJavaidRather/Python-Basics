# %% [markdown]
# First Program function

# %%
print("hello world")
# Out:
# hello world

# %% [markdown]
# Second program

# %%
print(10 + 3)
# Out:
# 13

# %% [markdown]
# Third one

# %%
print("Hi" + "Uzair")
# Out:
# HiUzair

# %% [markdown]
# variables
#
# Dynamic typing is done here
#
# type function

# %%
i=10
j=3.14
k= 'gate'
l= True

print(i,j,k,l)
print(type(i),type(j),type(k),type(l))
# Out:
# 10 3.14 gate True
# <class 'int'> <class 'float'> <class 'str'> <class 'bool'>

# %% [markdown]
# id function-----address

# %%
m=10
print(id(i))
# Out:
# 140725460104600

# %% [markdown]
# input function

# %%
#input----# used for single line comment in python === scanf() in c

name=input("Enter your name:")

# %%
print("Hello",name)
# Out:
# Hello uzair
