# %% [markdown]
# Exercise 1:
#
# 1. Prompt user to enter his/her name.
# 2. Prompt user to enter the number of study hours
# 3. Print user name along with number of study hours
# 4. Calculate number of hours user studies per week
# 5. Same as point 3 but now for an entire week
# 6. If hours per week less than 40 ,then print SSB else Gate

# %%
user = input("Enter your name:")
# Out:
# Enter your name: Uzair

# %%
hour = input("Enter the study hours:")
# Out:
# Enter the study hours: 5

# %%
print(user +" " +  "studies for " + hour +" "+ "hours per day")
# Out:
# Uzair studies for 5 hours per day

# %%
hour = int(hour) #typecasting
hrs = hour * 7

print(user + " "+ "studies" + " "+ str(hrs) + " " + " hours per week")
# Out:
# Uzair studies 35  hours per week

# %%
if hrs < 20:
    print("SSB")
else:
    print("Gate")
# Out:
# Gate

# %%
print(True or False)
# Out:
# True
