# %%
import codes

nest = [[1,2,3],[4,5,6],[7,8,9]]

# %%
codes.print_list(nest)
# Out:
# 	1
# 	2
# 	3
# 	4
# 	5
# 	6
# 	7
# 	8
# 	9

# %% [markdown]
# In Codes.py
#
# 1. print_list
# 2. print_tuple
# 3. print_set
