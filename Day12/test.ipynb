# %% [markdown]
# # Modules and Functions
#
# Resuable code is great, but a sharable module is better.
#
# Objective:
#
# Create, install and Distribute your own sharable modules.
# Make your functions sharable, so that everyone can use it.

# %% [markdown]
# What is a module?
#
# It is a text file containing your logic and saved with .(dot) py extension.

# %% [markdown]
# # Modules : The building Blocks
#
# Logical Encapsulation , Namespace Protection , Standard Practice

# %% [markdown]
# # Creating Your Module:

# %%
nested_list = [[1, 2, 3], [8, 9,10],[11, 12, 13]]

# %%
from codes import print_list    #namespace here is 'codes' i.e parent one

# %%
print_list(nested_list)
# Out:
# 1
# 2
# 3
# 8
# 9
# 10
# 11
# 12
# 13

# %% [markdown]
# Standard import :   import codes . function name
#
# Specific import :   from codes import print_list
#
# Alias import :      import codes as ns  . function name
